# %% [markdown]
# # Compare NLP Techniques: Prep The Data For Modeling

# %% [markdown]
# ### Read In & Clean Text

# %%
# Read in and clean data
import nltk
import numpy as np
import pandas as pd
import re
from sklearn.model_selection import train_test_split
import string

stopwords = nltk.corpus.stopwords.words('english')

messages = pd.read_csv('data/spam.csv', encoding='latin-1')
messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["label", "text"]
messages['label'] = np.where(messages['label']=='spam', 1, 0)

def clean_text(text):
    text = "".join([word.lower() for word in text if word not in string.punctuation])
    tokens = re.split('\W+', text)
    text = [word for word in tokens if word not in stopwords]
    return text

messages['clean_text'] = messages['text'].apply(lambda x: clean_text(x))
messages.head()
# Out:
#    label                                               text  \
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
#
#                                           clean_text
# 0  [go, jurong, point, crazy, available, bugis, n...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3      [u, dun, say, early, hor, u, c, already, say]
# 4  [nah, dont, think, goes, usf, lives, around, t...

# %%
# Split data into train and test set
X_train, X_test, y_train, y_test = train_test_split(messages['clean_text'],
                                                    messages['label'], test_size=0.2)

# %%
# Let's save the training and test sets to ensure we are using the same data for each model
X_train.to_csv('data/X_train.csv', index=False, header=True)
X_test.to_csv('data/X_test.csv', index=False, header=True)
y_train.to_csv('data/y_train.csv', index=False, header=True)
y_test.to_csv('data/y_test.csv', index=False, header=True)

# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('data/X_train.csv')
X_test = pd.read_csv('data/X_test.csv')
y_train = pd.read_csv('data/y_train.csv')
y_test = pd.read_csv('data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0  ['free', 'entry', 'å', '250', 'weekly', 'compe...
# 1  ['hi', 'darlin', 'cantdo', 'anythingtomorrow',...
# 2  ['wishing', 'family', 'merry', 'x', 'mas', 'ha...
# 3                   ['ìï', 'called', 'dad', 'oredi']
# 4                ['well', 'know', 'mean', 'texting']

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'free': 3126,
#  'entry': 2756,
#  '250': 408,
#  'weekly': 7839,
#  'competition': 2034,
#  'text': 7162,
#  'word': 7995,
#  'win': 7927,
#  '80086': 689,
#  '18': 342,
#  'tc': 7097,
#  'wwwtxttowincouk': 8090,
#  'hi': 3598,
#  'darlin': 2286,
#  'cantdo': 1729,
#  'anythingtomorrow': 1061,
#  'myparents': 4931,
#  'aretaking': 1113,
#  'outfor': 5311,
#  'meal': 4644,
#  'katexxx': 4105,
#  'wishing': 7950,
#  'family': 2911,
#  'merry': 4691,
#  'mas': 4607,
#  'happy': 3500,
#  'new': 5015,
#  'year': 8132,
#  'advance': 877,
#  'ìï': 8224,
#  'called': 1697,
#  'dad': 2261,
#  'oredi': 5285,
#  'well': 7854,
#  'know': 4179,
#  'mean': 4645,
#  'texting': 7168,
#  'dude': 2620,
#  'im': 3805,
#  'longer': 4420,
#  'pisces': 5523,
#  'aquarius': 1102,
#  'sure': 6999,
#  'driving': 2598,
#  'reach': 5909,
#  'destination': 2408,
#  'soon': 6682,
#  'goodmorning': 3344,
#  'today': 7325,
#  'late': 4248,
#  'ltdecimalgt': 4485,
#  'min': 4729,
#  'winner': 7937,
#  'mr': 4868,
#  'foley': 3058,
#  'ipod': 3925,
#  'exciting': 2838,
#  'prizes': 5736,
#  'keep': 4114,
#  'eye': 2878,
#  'ur': 7594,
#  'mobile': 4793,
#  'visit': 7702,
#  'wwwwin82050couk': 8091,
#  '11': 271,
#  'months': 4834,
#  'entitled': 2754,
#  'update': 7581,
#  'latest': 4254,
#  'colour': 2003,
#  'mobiles': 4794,
#  'camera': 1713,
#  'call': 1685,
#  'co': 1972,
#  '08002986030': 48,
#  '74355': 663,
#  'xmas': 8102,
#  'iscoming': 3938,
#  'awarded': 1231,
#  'either': 2694,
#  '500': 582,
#  'cd': 1790,
#  'gift': 3281,
#  'vouchers': 7723,
#  '100': 250,
#  'draw': 2580,
#  'txt': 7493,
#  'music': 4919,
#  '87066': 740,
#  'tnc': 7319,
#  'ill': 3802,
#  'work': 8001,
#  'something': 6663,
#  'hai': 3462,
#  'ana': 1017,
#  'tomarrow': 7344,
#  'coming': 2018,
#  'morning': 4843,
#  'sathy': 6252,
#  'go': 3309,
#  'rto': 6181,
#  'office': 5196,
#  'reply': 6039,
#  'came': 1712,
#  'home': 3653,
#  'phony': 5491,
#  '350': 489,
#  'award': 1230,
#  'todays': 7330,
#  'voda': 7711,
#  'numbers': 5150,
#  'ending': 2724,
#  'xxxx': 8110,
#  'selected': 6339,
#  'receive': 5942,
#  'match': 4614,
#  'please': 5556,
#  '08712300220': 89,
#  'quoting': 5859,
#  'claim': 1928,
#  'code': 1982,
#  '3100': 480,
#  'standard': 6803,
#  'rates': 5896,
#  'app': 1074,
#  'ok': 5217,
#  'vldo': 7710,
#  'got': 3359,
#  'adsense': 875,
#  'approved': 1094,
#  'yup': 8203,
#  'next': 5024,
#  'stop': 6862,
#  'audrie': 1199,
#  'lousy': 4454,
#  'autocorrect': 1210,
#  'probably': 5741,
#  'tomorrow': 7349,
#  'even': 2799,
#  'later': 4253,
#  'tonight': 7360,
#  'somethings': 6664,
#  'going': 3325,
#  'studies': 6909,
#  'alone': 982,
#  'without': 7957,
#  'anyones': 1056,
#  'help': 3562,
#  'cant': 1728,
#  'need': 4987,
#  'study': 6911,
#  'see': 6325,
#  'half': 3469,
#  'hour': 3698,
#  'jos': 4061,
#  'ask': 1155,
#  'wana': 7768,
#  'meet': 4661,
#  'recieve': 5953,
#  'tone': 7353,
#  'within': 7956,
#  '24hrs': 404,
#  'terms': 7150,
#  'conditions': 2063,
#  'channel': 1826,
#  'teletext': 7128,
#  'pg': 5476,
#  '750': 664,
#  'time': 7284,
#  'come': 2009,
#  'good': 3336,
#  'day': 2307,
#  'toopray': 7368,
#  'meremove': 4690,
#  'teeth': 7121,
#  'painful': 5349,
#  'maintaining': 4561,
#  'stuff': 6914,
#  'meeting': 4664,
#  'sir': 6534,
#  'waiting': 7750,
#  'letter': 4312,
#  '1s': 368,
#  'finish': 3002,
#  'urgent': 7597,
#  '07808726822': 33,
#  '2000': 382,
#  'bonus': 1498,
#  'caller': 1698,
#  'prize': 5735,
#  '020903': 10,
#  '2nd': 449,
#  'attempt': 1185,
#  'contact': 2090,
#  '08718729758': 136,
#  'box95qu': 1543,
#  'hey': 3592,
#  'want': 7770,
#  'crave': 2178,
#  'miss': 4757,
#  'love': 4457,
#  'ahmad': 927,
#  'saeed': 6214,
#  'al': 949,
#  'hallaq': 3472,
#  'talking': 7072,
#  'people': 5443,
#  'pay': 5418,
#  'agree': 920,
#  'price': 5716,
#  'pls': 5562,
#  'tell': 7129,
#  'really': 5924,
#  'buy': 1656,
#  'much': 4892,
#  'willing': 7925,
#  'subscribed': 6935,
#  'textcomp': 7165,
#  'wkly': 7967,
#  'comp': 2027,
#  '1st': 369,
#  'wks': 7968,
#  'question': 5844,
#  'follows': 3064,
#  'subsequent': 6940,
#  'charged150pmsg2': 1834,
#  'unsubscribe': 7575,
#  '84128custcare': 724,
#  '08712405020': 97,
#  'lor': 4433,
#  'rob': 6138,
#  'mack': 4534,
#  'gf': 3277,
#  'theater': 7198,
#  'lol': 4413,
#  'oops': 5256,
#  'sorry': 6694,
#  'fun': 3188,
#  'entered': 2747,
#  'cabin': 1674,
#  'pa': 5339,
#  'said': 6219,
#  'bday': 1338,
#  'boss': 1515,
#  'felt': 2958,
#  'special': 6729,
#  'askd': 1156,
#  'lunch': 4502,
#  'invited': 3913,
#  'apartment': 1068,
#  'went': 7863,
#  'hahahause': 3460,
#  'brain': 1554,
#  'dear': 2326,
#  'complimentary': 2043,
#  'trip': 7435,
#  'eurodisinc': 2792,
#  'trav': 7417,
#  'acoentry41': 840,
#  '1000': 251,
#  'dis': 2482,
#  '87121': 743,
#  '186å': 346,
#  '150morefrmmob': 305,
#  'shracomorsglsuplt10': 6488,
#  'ls1': 4478,
#  '3aj': 501,
#  'oh': 5210,
#  'yes': 8143,
#  'ive': 3972,
#  'little': 4380,
#  'weather': 7819,
#  'kind': 4148,
#  'coccooning': 1978,
#  'sunshine': 6978,
#  'quiz': 5855,
#  'top': 7370,
#  'sony': 6679,
#  'dvd': 2636,
#  'player': 5549,
#  'country': 2152,
#  'algarve': 964,
#  'ansr': 1041,
#  '82277': 704,
#  '150': 302,
#  'sptyrone': 6778,
#  'youre': 8184,
#  'still': 6850,
#  'maybe': 4638,
#  'leave': 4285,
#  'credit': 2187,
#  'card': 1738,
#  'get': 3269,
#  'gas': 3229,
#  'back': 1259,
#  'like': 4342,
#  'told': 7339,
#  'looks': 4427,
#  'wil': 7921,
#  'getting': 3275,
#  'headstart': 3529,
#  'leaving': 4287,
#  'bout': 1525,
#  '230ish': 400,
#  'desperate': 2406,
#  'company': 2030,
#  'could': 2145,
#  'head': 3523,
#  'earlierwe': 2644,
#  'goin': 3323,
#  'rummer': 6193,
#  'howz': 3713,
#  'persons': 5467,
#  'story': 6876,
#  'thanx': 7184,
#  'sending': 6356,
#  'take': 7061,
#  'didnt': 2440,
#  'phone': 5487,
#  'callon': 1704,
#  'friday': 3147,
#  'assume': 1167,
#  'wont': 7986,
#  'ringtone': 6122,
#  'sub': 6927,
#  'ringtoneget': 6124,
#  'week': 7835,
#  'freesend': 3137,
#  'subpoly': 6931,
#  '816183': 702,
#  'per': 5444,
#  'weekstop': 7841,
#  'sms08718727870': 6618,
#  'wow': 8027,
#  'think': 7230,
#  'common': 2025,
#  'freak': 3123,
#  'unless': 7563,
#  'chop': 1909,
#  'hr': 3717,
#  'posting': 5640,
#  'chennaibecause': 1868,
#  'working': 8003,
#  'dont': 2549,
#  'worry': 8016,
#  'guess': 3433,
#  'hes': 3588,
#  'busy': 1651,
#  'happen': 3490,
#  'tessypls': 7155,
#  'favor': 2938,
#  'convey': 2107,
#  'birthday': 1431,
#  'wishes': 7948,
#  'nimyapls': 5051,
#  'dnt': 2517,
#  'forget': 3087,
#  'shijas': 6433,
#  'dun': 2628,
#  'wear': 7815,
#  'jeans': 4015,
#  'awesome': 1233,
#  'click': 1948,
#  'delete': 2370,
#  'right': 6114,
#  'god': 3314,
#  'created': 2184,
#  'gap': 3221,
#  'fingers': 3001,
#  'one': 5237,
#  'made': 4542,
#  'comes': 2013,
#  'amp': 1009,
#  'fills': 2986,
#  'gaps': 3222,
#  'holding': 3645,
#  'hand': 3477,
#  'ta': 7045,
#  'jobs': 4037,
#  'available': 1213,
#  'let': 4310,
#  'cos': 2132,
#  'start': 6813,
#  'angry': 1025,
#  'dr': 2577,
#  'nokia': 5080,
#  'motorola': 4855,
#  'upto': 7592,
#  '12mths': 289,
#  '12price': 290,
#  'linerental': 4358,
#  'xnet': 8103,
#  'mins100txtmth': 4741,
#  'btooth': 1619,
#  'mobileupd8': 4797,
#  '08001950382': 46,
#  '2optoutd3wv': 454,
#  'would': 8024,
#  'appreciate': 1088,
#  'someone': 6656,
#  'talk': 7070,
#  'official': 5200,
#  'england': 2736,
#  'poly': 5597,
#  'flag': 3025,
#  'yer': 8142,
#  'tonights': 7361,
#  'game': 3215,
#  '84199': 725,
#  'optout': 5274,
#  'eng': 2731,
#  'box39822': 1538,
#  'w111wx': 7731,
#  'yessura': 8154,
#  'sun': 6971,
#  'tvlol': 7483,
#  'finishing': 3005,
#  'promises': 5770,
#  'though': 7246,
#  'havent': 3517,
#  'gotten': 3365,
#  'dinner': 2470,
#  'yet': 8157,
#  'secret': 6315,
#  'admirer': 867,
#  'looking': 4426,
#  'make': 4563,
#  'ufind': 7515,
#  'rreveal': 6174,
#  'thinks': 7233,
#  'specialcall': 6730,
#  '09058094599': 175,
#  'nowcan': 5127,
#  'film': 2987,
#  'yeah': 8130,
#  'list': 4371,
#  'joanna': 4035,
#  'feeling': 2951,
#  'anti': 1050,
#  'social': 6641,
#  'kyou': 4204,
#  'girl': 3288,
#  'reception': 5948,
#  'ah': 922,
#  'sms': 6617,
#  'ac': 818,
#  'sptv': 6777,
#  'jersey': 4022,
#  'devils': 2421,
#  'detroit': 2415,
#  'red': 5965,
#  'wings': 7935,
#  'play': 5547,
#  'ice': 3779,
#  'hockey': 3637,
#  'correct': 2128,
#  'incorrect': 3840,
#  'end': 2722,
#  'asked': 1157,
#  'dating': 2298,
#  'service': 6376,
#  '09058091854': 166,
#  'revealed': 6098,
#  'po': 5571,
#  'box385': 1537,
#  'm6': 4522,
#  '6wu': 655,
#  'found': 3109,
#  'diff': 2448,
#  'farm': 2922,
#  'shop': 6459,
#  'cheese': 1863,
#  'way': 7805,
#  'took': 7364,
#  'long': 4419,
#  'omw': 5234,
#  'wlcome': 7969,
#  'wonder': 7982,
#  'eaten': 2659,
#  'lion': 4364,
#  'nothing': 5113,
#  'sucks': 6947,
#  'hair': 3464,
#  'youll': 8179,
#  'belive': 1376,
#  'godnot': 3316,
#  'jesus': 4024,
#  'bored': 1509,
#  'housewives': 3704,
#  'chat': 1843,
#  'date': 2295,
#  '08717507711': 121,
#  'btnational': 1617,
#  'rate': 5895,
#  '10pmin': 268,
#  'landlines': 4230,
#  'money': 4820,
#  'lucky': 4496,
#  '88600': 753,
#  '1million': 362,
#  'give': 3294,
#  'away': 1232,
#  'ppt150x3normal': 5660,
#  'box403': 1539,
#  'w1t1jy': 7733,
#  'smoking': 6615,
#  'us': 7606,
#  'difficult': 2454,
#  'babe': 1250,
#  'doin': 2536,
#  'wot': 8021,
#  '2nite': 452,
#  'annie': 1031,
#  'uawakefeellikw': 7510,
#  'shitjustfound': 6446,
#  'via': 7671,
#  'aletter': 960,
#  'thatmum': 7191,
#  'gotmarried': 3362,
#  '4thnovbehind': 574,
#  'ourbacks': 5305,
#  'åð': 8220,
#  'fuckinniceselfish': 3179,
#  'video': 7677,
#  'tape': 7079,
#  'pple': 5657,
#  'type': 7505,
#  'message': 4695,
#  'wan': 7766,
#  'hee': 3548,
#  'noe': 5071,
#  'watch': 7790,
#  'infernal': 3856,
#  'affairs': 888,
#  'along': 983,
#  'asking': 1159,
#  'shuhui': 6494,
#  'oso': 5298,
#  'afternoon': 900,
#  'goes': 3320,
#  'woke': 7976,
#  'early': 2646,
#  'online': 5242,
#  'hmmm': 3629,
#  'italian': 3948,
#  'boy': 1545,
#  'grins': 3405,
#  'shit': 6443,
#  'awake': 1229,
#  'trying': 7455,
#  'shows': 6487,
#  'guaranteed': 3425,
#  '09066358361': 219,
#  'land': 4227,
#  'line': 4356,
#  'y87': 8117,
#  'valid': 7640,
#  '12hrs': 288,
#  'lar': 4240,
#  'double': 2563,
#  'check': 1851,
#  'wif': 7914,
#  'da': 2256,
#  'dresser': 2590,
#  'already': 985,
#  'wun': 8052,
#  'cut': 2244,
#  'short': 6467,
#  'look': 4422,
#  'nice': 5030,
#  'takes': 7065,
#  'child': 1887,
#  'afraid': 895,
#  'dark': 2283,
#  'become': 1348,
#  'teenager': 7120,
#  'wants': 7774,
#  'stay': 6826,
#  'night': 5038,
#  '8007': 687,
#  '25p': 412,
#  'alfie': 963,
#  'moons': 4837,
#  'children': 1890,
#  'song': 6676,
#  'mob': 4791,
#  'm8s': 4524,
#  'charity': 1836,
#  'nokias': 5084,
#  'polys': 5604,
#  'zed': 8210,
#  '08701417012': 66,
#  'profit': 5761,
#  'nope': 5096,
#  'mapquest': 4589,
#  'usf': 7615,
#  'dogwood': 2535,
#  'drive': 2595,
#  'teach': 7106,
#  'ship': 6438,
#  'cars': 1763,
#  'baby': 1253,
#  'hope': 3675,
#  'okay': 5218,
#  'every': 2805,
#  'ure': 7595,
#  'touch': 7389,
#  'youdoing': 8175,
#  'sar': 6243,
#  'xxx': 8109,
#  'enc': 2721,
#  'ltgt': 4488,
#  'paper': 5366,
#  'morn': 4841,
#  'aft': 898,
#  'tmr': 7316,
#  'anyway': 1063,
#  'hopeing': 3679,
#  'pissed': 5525,
#  'remember': 6010,
#  'gone': 3331,
#  'sisters': 6541,
#  'yogasana': 8166,
#  'coz': 2164,
#  'cine': 1922,
#  'bathe': 1313,
#  'hav': 3516,
#  'steam': 6834,
#  'bath': 1312,
#  'minutes': 4747,
#  'juz': 4081,
#  'vday': 7655,
#  'parachute': 5369,
#  'coins': 1987,
#  'must': 4921,
#  'timings': 7293,
#  'msg': 4874,
#  'xuhui': 8105,
#  'learn': 4280,
#  'may': 4636,
#  'lesson': 4308,
#  '8am': 764,
#  'sick': 6501,
#  'shopping': 6461,
#  'pain': 5348,
#  'catch': 1777,
#  'omg': 5233,
#  'freaking': 3124,
#  'shes': 6430,
#  'looked': 4424,
#  'thru': 7262,
#  'friends': 3153,
#  'find': 2994,
#  'photos': 5493,
#  'myspace': 4933,
#  'logged': 4406,
#  'gd': 3246,
#  'luck': 4493,
#  'exams': 2833,
#  'jay': 4006,
#  'says': 6271,
#  'doublefaggot': 2564,
#  'thank': 7178,
#  'monday': 4818,
#  'divorce': 2510,
#  'march': 4592,
#  'ready': 5916,
#  'problem': 5742,
#  'capital': 1733,
#  'never': 5012,
#  'complete': 2039,
#  'far': 2921,
#  'hows': 3711,
#  'ladies': 4217,
#  'snow': 6634,
#  'enjoy': 2738,
#  'lmao': 4389,
#  'needing': 4990,
#  'anymore': 1054,
#  'boo': 1499,
#  'enjoyin': 2740,
#  'yourjob': 8186,
#  'seemed': 6331,
#  'gettin': 3274,
#  'hunnyhope': 3751,
#  'oktake': 5227,
#  'care': 1742,
#  'iåõllspeak': 3978,
#  '2u': 462,
#  'soonlots': 6685,
#  'loveme': 4462,
#  'jon': 4055,
#  'pete': 5472,
#  'bin': 1422,
#  'spain': 6722,
#  'recently': 5947,
#  'sum': 6964,
#  'dinero': 2467,
#  'left': 4291,
#  'bill': 1416,
#  'åôrents': 8222,
#  'mayb': 4637,
#  'interested': 3898,
#  '12000pes': 278,
#  'around': 1130,
#  '48': 553,
#  'tb': 7095,
#  'james': 3992,
#  'congrats': 2075,
#  '3g': 505,
#  'videophones': 7679,
#  '09061744553': 194,
#  'videochat': 7678,
#  'wid': 7912,
#  'mates': 4618,
#  'java': 4005,
#  'games': 3216,
#  'dload': 2516,
#  'polyh': 5601,
#  'noline': 5085,
#  'rentl': 6027,
#  'bx420': 1665,
#  'ip4': 3921,
#  '5we': 612,
#  '150pm': 312,
#  'gave': 3234,
#  'boston': 1516,
#  'men': 4680,
#  'changed': 1823,
#  'search': 6307,
#  'location': 4399,
#  'nyc': 5163,
#  'cuz': 2251,
#  'signin': 6512,
#  'page': 5345,
#  'haiyoh': 3467,
#  'hamster': 3476,
#  'jealous': 4014,
#  'million': 4726,
#  'questions': 5846,
#  'mistake': 4768,
#  'days': 2310,
#  'ringtoneking': 6125,
#  '84484': 726,
#  'arent': 1111,
#  'hours': 3700,
#  'imma': 3812,
#  'flip': 3038,
#  'fine': 2996,
#  'difficulties': 2455,
#  'works': 8006,
#  'mine': 4733,
#  'send': 6353,
#  'another': 1039,
#  'friend': 3151,
#  'request': 6047,
#  'aight': 935,
#  'closer': 1958,
#  'tyler': 7503,
#  'two': 7492,
#  'trips': 7437,
#  'ha': 3453,
#  'jus': 4079,
#  'ate': 1176,
#  'honey': 3664,
#  'ar': 1103,
#  'sweet': 7021,
#  'nvm': 5159,
#  'sport': 6768,
#  'shoes': 6456,
#  'leh': 4296,
#  'yunny': 8201,
#  'understand': 7544,
#  'wed': 7826,
#  'nite': 5054,
#  'til': 7281,
#  'eta': 2784,
#  'taunton': 7088,
#  '1230': 282,
#  'planned': 5542,
#  'okday': 5219,
#  'xx': 8106,
#  'mmmmmm': 4783,
#  'youso': 8187,
#  'wait': 7746,
#  'begin': 1368,
#  'second': 6312,
#  'side': 6504,
#  'specially': 6734,
#  'cash': 1767,
#  'speak': 6727,
#  'live': 4381,
#  'operator': 5262,
#  '087147123779am7pm': 104,
#  'cost': 2134,
#  '10p': 267,
#  'great': 3393,
#  'doctor': 2524,
#  'india': 3847,
#  'drink': 2591,
#  'appy': 1098,
#  'fizz': 3024,
#  'contains': 2093,
#  'cancer': 1722,
#  'causing': 1784,
#  'age': 907,
#  'wat': 7789,
#  'makes': 4564,
#  'thk': 7237,
#  'fall': 2906,
#  'actually': 851,
#  'quite': 5852,
#  'prone': 5774,
#  'falls': 2908,
#  'fetch': 2962,
#  'bring': 1584,
#  'measure': 4652,
#  'fri': 3146,
#  'attended': 1188,
#  'hate': 3513,
#  'turns': 7479,
#  'annoying': 1036,
#  'everything': 2813,
#  'house': 3701,
#  'yo': 8164,
#  'carlos': 1756,
#  'weekend': 7837,
#  'knw': 4187,
#  'ru': 6182,
#  'aathilove': 800,
#  'lot': 4442,
#  'rcv': 5905,
#  'msgs': 4878,
#  'svc': 7011,
#  'hardcore': 3502,
#  'services': 6377,
#  '69988': 642,
#  'verify': 7665,
#  'yr': 8196,
#  'network': 5008,
#  'try': 7453,
#  'number': 5147,
#  'watching': 7794,
#  'tv': 7481,
#  'funny': 3196,
#  'bluff': 1482,
#  'izzit': 3976,
#  'impossible': 3822,
#  'completely': 2041,
#  'forgot': 3091,
#  'pop': 5614,
#  'em': 2709,
#  'round': 6163,
#  'thangam': 7176,
#  'held': 3551,
#  'prasad': 5672,
#  'checking': 1855,
#  'happening': 3494,
#  'area': 1110,
#  'wine': 7933,
#  'dine': 2465,
#  'lady': 4219,
#  'taught': 7087,
#  'ranjith': 5892,
#  'becaus': 1347,
#  'verifying': 7666,
#  'project': 5764,
#  'prabu': 5663,
#  'hello': 3556,
#  'interview': 3903,
#  'meare': 4651,
#  'missing': 4761,
#  'letters': 4313,
#  'ûªm': 8227,
#  'expecting': 2853,
#  'orange': 5277,
#  'ûªt': 8228,
#  'say': 6268,
#  '200': 381,
#  'spree': 6774,
#  'starting': 6817,
#  'store': 6872,
#  '88039': 747,
#  'skilgme': 6554,
#  'tscs08714740323': 7459,
#  '1winawk': 377,
#  'age16': 908,
#  '150perweeksub': 310,
#  'ard': 1108,
#  'christmas': 1915,
#  'kate': 4104,
#  'lovely': 4461,
#  'sing': 6526,
#  'guy': 3445,
#  'naughty': 4971,
#  'pix': 5527,
#  'whats': 7883,
#  'teresa': 7147,
#  'hear': 3534,
#  'received': 5944,
#  'package': 5341,
#  'since': 6523,
#  'dec': 2339,
#  'thot': 7244,
#  'yould': 8178,
#  'fantastic': 2919,
#  'best': 1392,
#  'reading': 5915,
#  'plus': 5567,
#  'bam': 1278,
#  'first': 3012,
#  'aid': 932,
#  'usmle': 7619,
#  'done': 2547,
#  'gym': 3450,
#  'also': 991,
#  'wesley': 7869,
#  'howve': 3712,
#  'eat': 2658,
#  '07xxxxxxxxx': 39,
#  '020603': 5,
#  '09066362231': 223,
#  'asap': 1147,
#  'box97n7qp': 1544,
#  '150ppm': 322,
#  'solve': 6651,
#  'case': 1766,
#  'man': 4573,
#  'murdered': 4915,
#  '1his': 357,
#  'wife': 7915,
#  'police': 5594,
#  '2police': 456,
#  'questioned': 5845,
#  'everyone': 2810,
#  '3wife': 521,
#  'siri': 6535,
#  'sleeping': 6571,
#  'murder': 4914,
#  'place': 5531,
#  '4cook': 558,
#  'cooking': 2116,
#  '5gardener': 600,
#  'picking': 5502,
#  'vegetables': 7657,
#  '6housemaid': 646,
#  'post': 5634,
#  '7children': 675,
#  '8neighbour': 770,
#  'marriage': 4601,
#  'arrested': 1136,
#  'murderer': 4916,
#  'immediately': 3814,
#  'whos': 7905,
#  'reason': 5928,
#  'brilliant': 1580,
#  'yeshe': 8150,
#  'crickiting': 2196,
#  'mind': 4731,
#  'bothering': 1519,
#  'trust': 7449,
#  'answers': 1046,
#  'haha': 3459,
#  'pleased': 5557,
#  'inform': 3860,
#  'application': 1081,
#  'airtel': 940,
#  'broadband': 1594,
#  'processed': 5752,
#  'successfully': 6944,
#  'installation': 3888,
#  'full': 3186,
#  'sent': 6364,
#  'explain': 2863,
#  'whatsup': 7884,
#  'sleep': 6569,
#  'many': 4587,
#  'modelsony': 4805,
#  'ericson': 2764,
#  'der': 2397,
#  'luks': 4500,
#  'bt': 1615,
#  'modl': 4806,
#  'mom': 4813,
#  'might': 4720,
#  'thanks': 7179,
#  'order': 5282,
#  'ref': 5971,
#  'r836': 5860,
#  'charged': 1833,
#  '450': 546,
#  'arrive': 1138,
#  'customer': 2241,
#  '09065069154': 210,
#  'thats': 7193,
#  'drugs': 2607,
#  'heard': 3535,
#  'anything': 1059,
#  'answering': 1045,
#  'texts': 7171,
#  ...}

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.783 / Accuracy: 0.97

# %% [markdown]
# # Compare NLP Techniques: Build Model On word2vec Vectors

# %%
# Load the cleaned training and test sets
import gensim
import numpy as np
import pandas as pd

X_train = pd.read_csv('data/X_train.csv')
X_test = pd.read_csv('data/X_test.csv')
y_train = pd.read_csv('data/y_train.csv')
y_test = pd.read_csv('data/y_test.csv')

# %% [markdown]
# ### Create word2vec Vectors

# %%
# Train a basic word2vec model
w2v_model = gensim.models.Word2Vec(X_train,
                                   vector_size=100,
                                   window=5,
                                   min_count=2)

# %%
# Replace the words in each text message with the learned word vector
words = list(w2v_model.wv.index_to_key)
X_train_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
                         for ls in X_train['clean_text']], dtype=object)
X_test_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
                         for ls in X_test['clean_text']], dtype=object)

# %%
# Average the word vectors for each sentence (and assign a vector of zeros if the model
# did not learn any of the words in the text message during training
X_train_vect_avg = []
for v in X_train_vect:
    if v.size:
        X_train_vect_avg.append(v.mean(axis=0))
    else:
        X_train_vect_avg.append(np.zeros(100, dtype=float))
        
X_test_vect_avg = []
for v in X_test_vect:
    if v.size:
        X_test_vect_avg.append(v.mean(axis=0))
    else:
        X_test_vect_avg.append(np.zeros(100, dtype=float))

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Word Vectors

# %%
# Instantiate and fit a basic Random Forest model on top of the vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect_avg, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect_avg)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 0.481 / Recall: 0.236 / Accuracy: 0.857

# %% [markdown]
# # Compare NLP Techniques: Build Model On doc2vec Vectors

# %%
# Load the cleaned training and test sets
import gensim
import numpy as np
import pandas as pd

X_train = pd.read_csv('data/X_train.csv')
X_test = pd.read_csv('data/X_test.csv')
y_train = pd.read_csv('data/y_train.csv')
y_test = pd.read_csv('data/y_test.csv')

# %% [markdown]
# ### Create doc2vec Vectors

# %%
# Created TaggedDocument vectors for each text message in the training and test sets
tagged_docs_train = [gensim.models.doc2vec.TaggedDocument(v, [i])
                     for i, v in enumerate(X_train['clean_text'])]
tagged_docs_test = [gensim.models.doc2vec.TaggedDocument(v, [i])
                    for i, v in enumerate(X_test['clean_text'])]

# %%
# Train a basic doc2vec model
d2v_model = gensim.models.Doc2Vec(tagged_docs_train,
                                  vector_size=100,
                                  window=5,
                                  min_count=2)

# %%
# Infer the vectors to be used in training and testing
train_vectors = [d2v_model.infer_vector(eval(v.words)) for v in tagged_docs_train]
test_vectors = [d2v_model.infer_vector(eval(v.words)) for v in tagged_docs_test]

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Document Vectors

# %%
# Fit a basic model, make predictions on the holdout test set, and the generate the evaluation metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score

rf = RandomForestClassifier()
rf_model = rf.fit(train_vectors, y_train.values.ravel())

y_pred = rf_model.predict(test_vectors)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 0.967 / Recall: 0.369 / Accuracy: 0.909

# %% [markdown]
# # Compare NLP Techniques: Build A Basic RNN

# %%
# Load the cleaned training and test sets
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import pandas as pd

X_train = pd.read_csv('data/X_train.csv')
X_test = pd.read_csv('data/X_test.csv')
y_train = pd.read_csv('data/y_train.csv')
y_test = pd.read_csv('data/y_test.csv')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Prep Data

# %%
# Train the tokenizer and use that tokenizer to convert the sentences to sequences of numbers
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train['clean_text'])
X_train_seq = tokenizer.texts_to_sequences(X_train['clean_text'])
X_test_seq = tokenizer.texts_to_sequences(X_test['clean_text'])

# %%
# Pad the sequences so each sequence is the same length
X_train_seq_padded = pad_sequences(X_train_seq, 50)
X_test_seq_padded = pad_sequences(X_test_seq, 50)

# %% [markdown]
# ### Build And Evaluate RNN

# %%
# Import the tools needed and use our previously defined functions to calculate precision and recall
import keras.backend as K
from keras.layers import Dense, Embedding, LSTM
from keras.models import Sequential

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

# %%
# Construct our basic RNN model framework
model = Sequential()

model.add(Embedding(len(tokenizer.index_word)+1, 32))
model.add(LSTM(32, dropout=0, recurrent_dropout=0))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 32)          264576
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                8320
# _________________________________________________________________
# dense (Dense)                (None, 32)                1056
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 273,985
# Trainable params: 273,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', precision_m, recall_m])

# %%
# Fit the RNN
history = model.fit(X_train_seq_padded, y_train['label'], 
                    batch_size=32, epochs=10,
                    validation_data=(X_test_seq_padded, y_test))
# Out:
# Epoch 1/10
# 140/140 [==============================] - 3s 22ms/step - loss: 0.2373 - accuracy: 0.9266 - precision_m: 0.5813 - recall_m: 0.4622 - val_loss: 0.0922 - val_accuracy: 0.9749 - val_precision_m: 0.9714 - val_recall_m: 0.8133
# Epoch 2/10
# 140/140 [==============================] - 3s 18ms/step - loss: 0.0356 - accuracy: 0.9901 - precision_m: 0.9591 - recall_m: 0.9217 - val_loss: 0.0623 - val_accuracy: 0.9830 - val_precision_m: 1.0000 - val_recall_m: 0.8806
# Epoch 3/10
# 140/140 [==============================] - 2s 18ms/step - loss: 0.0084 - accuracy: 0.9978 - precision_m: 0.9978 - recall_m: 0.9886 - val_loss: 0.0558 - val_accuracy: 0.9848 - val_precision_m: 0.9943 - val_recall_m: 0.9028
# Epoch 4/10
# 140/140 [==============================] - 7s 50ms/step - loss: 0.0027 - accuracy: 0.9993 - precision_m: 0.9917 - recall_m: 0.9905 - val_loss: 0.0563 - val_accuracy: 0.9830 - val_precision_m: 0.9819 - val_recall_m: 0.9028
# Epoch 5/10
# 140/140 [==============================] - 3s 19ms/step - loss: 0.0013 - accuracy: 0.9998 - precision_m: 1.0000 - recall_m: 0.9990 - val_loss: 0.0611 - val_accuracy: 0.9848 - val_precision_m: 0.9943 - val_recall_m: 0.9028
# Epoch 6/10
# 140/140 [==============================] - 2s 17ms/step - loss: 8.1170e-04 - accuracy: 0.9998 - precision_m: 0.9929 - recall_m: 0.9911 - val_loss: 0.0680 - val_accuracy: 0.9848 - val_precision_m: 0.9943 - val_recall_m: 0.9028
# Epoch 7/10
# 140/140 [==============================] - 3s 18ms/step - loss: 2.7620e-04 - accuracy: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0721 - val_accuracy: 0.9839 - val_precision_m: 0.9914 - val_recall_m: 0.9028
# Epoch 8/10
# 140/140 [==============================] - 3s 18ms/step - loss: 1.5038e-04 - accuracy: 1.0000 - precision_m: 0.9857 - recall_m: 0.9857 - val_loss: 0.0781 - val_accuracy: 0.9848 - val_precision_m: 0.9943 - val_recall_m: 0.9028
# Epoch 9/10
# 140/140 [==============================] - 3s 22ms/step - loss: 1.0181e-04 - accuracy: 1.0000 - precision_m: 0.9929 - recall_m: 0.9929 - val_loss: 0.0802 - val_accuracy: 0.9839 - val_precision_m: 0.9914 - val_recall_m: 0.9028
# Epoch 10/10
# 140/140 [==============================] - 3s 22ms/step - loss: 6.9404e-05 - accuracy: 1.0000 - precision_m: 1.0000 - recall_m: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9848 - val_precision_m: 0.9943 - val_recall_m: 0.9028

# %%
# Plot basic evaluation metrics across epochs
import matplotlib.pyplot as plt
# %matplotlib inline

for i in ['accuracy', 'precision_m', 'recall_m']:
    acc = history.history[i]
    val_acc = history.history['val_{}'.format(i)]
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize = (10,5))
    plt.plot(epochs, acc, label='Training Accuracy')
    plt.plot(epochs, val_acc, label='Validation Accuracy')
    plt.title('Results for {}'.format(i))
    plt.legend()
    plt.show()
