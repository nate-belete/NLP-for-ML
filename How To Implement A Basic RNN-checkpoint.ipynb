# %% [markdown]
# # RNNs: How To Implement A Basic RNN

# %% [markdown]
# ### Read In, Clean, And Split The Data

# %%
# Read in data and split into training and test set
# NOTE: we are NOT cleaning the data
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 1000)

messages = pd.read_csv('../../../data/spam.csv', encoding='latin-1')
messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["label", "text"]
labels = np.where(messages['label']=='spam', 1, 0)

X_train, X_test, y_train, y_test = train_test_split(messages['text'],
                                                    labels, test_size=0.2)

# %% [markdown]
# ### Prep Data For Modeling

# %%
# Install keras
# !pip install keras --user

# %%
# Import the tools we will need from keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
# Out:
# Using TensorFlow backend.

# %%
# Initialize and fit the tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
# Use that tokenizer to transform the text messages in the training and test sets
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

# %%
# Pad the sequences so each sequence is the same length
X_train_seq_padded = pad_sequences(X_train_seq, 50)
X_test_seq_padded = pad_sequences(X_test_seq, 50)

# %% [markdown]
# ### Build Model

# %%
# Import the tools needed from keras and define functions to calculate recall and precision
import keras.backend as K
from keras.layers import Dense, Embedding, LSTM
from keras.models import Sequential

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

# %%
# Construct a simple RNN model
model = Sequential()

model.add(Embedding(len(tokenizer.index_word)+1, 32))
model.add(LSTM(32, dropout=0, recurrent_dropout=0))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 32)          254464
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                8320
# _________________________________________________________________
# dense (Dense)                (None, 32)                1056
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 263,873
# Trainable params: 263,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', precision_m, recall_m])

# %%
# Fit the RNN model
history = model.fit(X_train_seq_padded, y_train, 
                    batch_size=32, epochs=10,
                    validation_data=(X_test_seq_padded, y_test))
# Out:
# Epoch 1/10
# 140/140 [==============================] - 8s 58ms/step - loss: 0.2429 - accuracy: 0.9197 - precision_m: 0.5324 - recall_m: 0.4372 - val_loss: 0.0932 - val_accuracy: 0.9731 - val_precision_m: 0.8681 - val_recall_m: 0.8181
# Epoch 2/10
# 140/140 [==============================] - 5s 39ms/step - loss: 0.0361 - accuracy: 0.9906 - precision_m: 0.9769 - recall_m: 0.9432 - val_loss: 0.0638 - val_accuracy: 0.9830 - val_precision_m: 0.9371 - val_recall_m: 0.8481
# Epoch 3/10
# 140/140 [==============================] - 5s 36ms/step - loss: 0.0139 - accuracy: 0.9969 - precision_m: 0.9890 - recall_m: 0.9727 - val_loss: 0.0683 - val_accuracy: 0.9865 - val_precision_m: 0.9429 - val_recall_m: 0.8612
# Epoch 4/10
# 140/140 [==============================] - 5s 33ms/step - loss: 0.0064 - accuracy: 0.9989 - precision_m: 0.9929 - recall_m: 0.9833 - val_loss: 0.0678 - val_accuracy: 0.9883 - val_precision_m: 0.9429 - val_recall_m: 0.8754
# Epoch 5/10
# 140/140 [==============================] - 5s 33ms/step - loss: 0.0030 - accuracy: 0.9993 - precision_m: 0.9857 - recall_m: 0.9807 - val_loss: 0.0571 - val_accuracy: 0.9865 - val_precision_m: 0.9286 - val_recall_m: 0.8843
# Epoch 6/10
# 140/140 [==============================] - 5s 32ms/step - loss: 0.0016 - accuracy: 0.9998 - precision_m: 0.9571 - recall_m: 0.9563 - val_loss: 0.0636 - val_accuracy: 0.9883 - val_precision_m: 0.9429 - val_recall_m: 0.8795loss: 0.0016 - accuracy: 0.9998 - precision_m: 0.9556 - recall_m: 0.9
# Epoch 7/10
# 140/140 [==============================] - 4s 30ms/step - loss: 5.6558e-04 - accuracy: 1.0000 - precision_m: 0.9929 - recall_m: 0.9929 - val_loss: 0.0859 - val_accuracy: 0.9857 - val_precision_m: 0.9429 - val_recall_m: 0.8612
# Epoch 8/10
# 140/140 [==============================] - 4s 29ms/step - loss: 2.6226e-04 - accuracy: 1.0000 - precision_m: 0.9857 - recall_m: 0.9857 - val_loss: 0.0768 - val_accuracy: 0.9874 - val_precision_m: 0.9381 - val_recall_m: 0.8795
# Epoch 9/10
# 140/140 [==============================] - 4s 29ms/step - loss: 1.1195e-04 - accuracy: 1.0000 - precision_m: 0.9929 - recall_m: 0.9929 - val_loss: 0.0930 - val_accuracy: 0.9865 - val_precision_m: 0.9429 - val_recall_m: 0.8659
# Epoch 10/10
# 140/140 [==============================] - 5s 34ms/step - loss: 5.5352e-05 - accuracy: 1.0000 - precision_m: 0.9857 - recall_m: 0.9857 - val_loss: 0.0965 - val_accuracy: 0.9865 - val_precision_m: 0.9429 - val_recall_m: 0.8659

# %%
# Plot the evaluation metrics by each epoch for the model to see if we are over or underfitting
import matplotlib.pyplot as plt

for i in ['accuracy', 'precision_m', 'recall_m']:
    acc = history.history[i]
    val_acc = history.history['val_{}'.format(i)]
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize = (10,5))
    plt.plot(epochs, acc, label='Training Accuracy')
    plt.plot(epochs, val_acc, label='Validation Accuracy')
    plt.title('Results for {}'.format(i))
    plt.legend()
    plt.show()
